# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # About the dataset....

# %% [markdown]
# ### .This dataset is taken from Kaggle.

# %% [markdown]
# ### .Survey results on Cryptocurrency Prices, Charts And Market Capitalizations

# %% [markdown]
# # Importing libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
# ignore all warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing dataset....

# %%
data=pd.read_csv(r"C:\Users\OFF-LAPTOP\Downloads\coinmarketcap_06122017.csv")
data.head()
# Out:
#    Unnamed: 0  24h_volume_usd  available_supply            id  last_updated  \
# 0           0    9.007640e+09      1.672352e+07       bitcoin    1512549554
# 1           1    1.551330e+09      9.616537e+07      ethereum    1512549553
# 2           2    1.111350e+09      1.684044e+07  bitcoin-cash    1512549578
# 3           3    2.936090e+09      2.779530e+09          iota    1512549571
# 4           4    2.315050e+08      3.873915e+10        ripple    1512549541
#
#    market_cap_usd    max_supply          name  percent_change_1h  \
# 0    2.130493e+11  2.100000e+07       Bitcoin               0.12
# 1    4.352945e+10           NaN      Ethereum              -0.18
# 2    2.529585e+10  2.100000e+07  Bitcoin Cash               1.65
# 3    1.475225e+10  2.779530e+09          IOTA              -2.38
# 4    9.365343e+09  1.000000e+11        Ripple               0.56
#
#    percent_change_24h  percent_change_7d  price_btc     price_usd  rank  \
# ...

# %% [markdown]
# # Checking dataset...

# %%
data.shape
# Out:
# (1326, 16)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', '24h_volume_usd', 'available_supply', 'id',
#        'last_updated', 'market_cap_usd', 'max_supply', 'name',
#        'percent_change_1h', 'percent_change_24h', 'percent_change_7d',
#        'price_btc', 'price_usd', 'rank', 'symbol', 'total_supply'],
#       dtype='object')

# %%
data.drop(columns="id",inplace=True)

# %%
data.drop(columns="max_supply",inplace=True)

# %%
data.total_supply.fillna("7.849645e+11")
# Out:
# 0          16723525.0
# 1          96165368.0
# 2          16840438.0
# 3        2779530283.0
# 4       99993093880.0
#             ...
# 1321     7.849645e+11
# 1322     7.849645e+11
# 1323        2502380.0
# 1324    10200000000.0
# 1325       10000000.0
# Name: total_supply, Length: 1326, dtype: object

# %%
data.drop(columns="symbol",inplace=True)

# %%
data=data.dropna()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 971 entries, 0 to 1030
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          971 non-null    int64
#  1   24h_volume_usd      971 non-null    float64
#  2   available_supply    971 non-null    float64
#  3   last_updated        971 non-null    int64
#  4   market_cap_usd      971 non-null    float64
#  5   name                971 non-null    object
#  6   percent_change_1h   971 non-null    float64
#  7   percent_change_24h  971 non-null    float64
#  8   percent_change_7d   971 non-null    float64
#  9   price_btc           971 non-null    float64
#  10  price_usd           971 non-null    float64
#  11  rank                971 non-null    int64
#  12  total_supply        971 non-null    float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 106.2+ KB

# %%
data
# Out:
#       Unnamed: 0  24h_volume_usd  available_supply  last_updated  \
# 0              0    9.007640e+09      1.672352e+07    1512549554
# 1              1    1.551330e+09      9.616537e+07    1512549553
# 2              2    1.111350e+09      1.684044e+07    1512549578
# 3              3    2.936090e+09      2.779530e+09    1512549571
# 4              4    2.315050e+08      3.873915e+10    1512549541
# ...          ...             ...               ...           ...
# 1023        1023    4.606890e+00      5.826388e+06    1512549552
# 1024        1024    2.231020e+02      4.213000e+05    1512549567
# 1027        1027    5.108100e-01      1.327175e+08    1512549571
# 1028        1028    4.271860e+01      8.714000e+04    1512549561
# 1030        1030    1.718820e+02      7.924200e+04    1512549575
#
#       market_cap_usd                name  percent_change_1h  \
# 0       2.130493e+11             Bitcoin               0.12
# 1       4.352945e+10            Ethereum              -0.18
# ...

# %%
data.dtypes
# Out:
# Unnamed: 0              int64
# 24h_volume_usd        float64
# available_supply      float64
# last_updated            int64
# market_cap_usd        float64
# name                   object
# percent_change_1h     float64
# percent_change_24h    float64
# percent_change_7d     float64
# price_btc             float64
# price_usd             float64
# rank                    int64
# total_supply          float64
# dtype: object

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data.describe()
# Out:
#         Unnamed: 0  24h_volume_usd  available_supply  last_updated  \
# count   971.000000    9.710000e+02      9.710000e+02  9.710000e+02
# mean    494.978373    2.144745e+07      9.176065e+09  1.512550e+09
# std     291.852622    3.132805e+08      1.175089e+11  1.371135e+01
# min       0.000000    8.678570e-02      0.000000e+00  1.512550e+09
# 25%     243.500000    6.513705e+02      5.837484e+06  1.512550e+09
# 50%     489.000000    1.135790e+04      2.381221e+07  1.512550e+09
# 75%     741.500000    4.498840e+05      1.186637e+08  1.512550e+09
# max    1030.000000    9.007640e+09      3.209033e+12  1.512550e+09
#
#        market_cap_usd  percent_change_1h  percent_change_24h  \
# count    9.710000e+02         971.000000          971.000000
# mean     3.854009e+08           1.009815            9.346735
# std      7.052861e+09          10.522555           46.883783
# min      1.000000e+01         -49.430000          -94.220000
# ...

# %% [markdown]
# # Checking the corelation....

# %%
data.corr()  #Correlation is checked with the numeric data
# Out:
#                     Unnamed: 0  24h_volume_usd  available_supply  \
# Unnamed: 0            1.000000       -0.113543         -0.021443
# 24h_volume_usd       -0.113543        1.000000         -0.004524
# available_supply     -0.021443       -0.004524          1.000000
# last_updated         -0.124301       -0.018993         -0.045854
# market_cap_usd       -0.091279        0.962900         -0.003280
# percent_change_1h     0.029168       -0.006792         -0.015504
# percent_change_24h    0.052043        0.012028          0.058611
# percent_change_7d    -0.052850        0.012361         -0.013690
# price_btc             0.040022        0.164265         -0.004564
# price_usd             0.039823        0.167142         -0.004570
# rank                  1.000000       -0.113543         -0.021443
# total_supply          0.032250       -0.002255          0.005663
#
#                     last_updated  market_cap_usd  percent_change_1h  \
# ...

# %% [markdown]
# # Checking the missing values

# %%
data.isnull().sum()

# %% [markdown]
# # DATA VISUALIZATION

# %%
plt.figure(figsize=(28,6))
sns.histplot(data['percent_change_24h'])
# Out:
# <AxesSubplot:xlabel='percent_change_24h', ylabel='Count'>

# %%
plt.figure(figsize=(40,20))
sns.histplot(data['percent_change_24h'])
# Out:
# <AxesSubplot:xlabel='percent_change_24h', ylabel='Count'>

# %%
plt.figure(figsize=(19,8))
sns.heatmap(data.corr(),annot=True,cmap="ocean_r")
# Out:
# <AxesSubplot:>

# %%
sns.countplot(data["percent_change_7d"])
# Out:
# <AxesSubplot:xlabel='percent_change_7d', ylabel='count'>

# %%
plt.figure(figsize=(8,6))
sns.countplot(x=data['percent_change_7d'])
# Out:
# <AxesSubplot:xlabel='percent_change_7d', ylabel='count'>

# %%
data["percent_change_24h"].value_counts().plot.pie(title="percent_change_24h", autopct='%.2f',
                                    figsize=(6, 6));
